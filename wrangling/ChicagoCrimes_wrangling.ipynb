# %%
import pandas as pd
import numpy as np

DATASETS_LOCATION = "/Users/gomerudo/workspace/datasets"

# %% [markdown]
# ## Load clean datasets

# %%
# Loading from absolute path, because the dataset is too big to download and to upload

DATASET_CRIMES_PATH = DATASETS_LOCATION + "/chicago_crimes_2001_present_clean.csv"
DATASET_INDICATORS_PATH = DATASETS_LOCATION + "/chicago_socioeconomic_indicators_2008_2012_clean.csv"

# Load CSVs
crimes_df = pd.read_csv(DATASET_CRIMES_PATH, na_values = ["", " "])
indicators_df = pd.read_csv(DATASET_INDICATORS_PATH, na_values = ["", " "])

# %%
# Show preview of crimes
crimes_df.head()
# Out:
#          ID Case Number                    Date                   Block  IUCR  \
# 0  10000092    HY189866  03/18/2015 07:44:00 PM         047XX W OHIO ST  041A
# 1  10000094    HY190059  03/18/2015 11:00:00 PM  066XX S MARSHFIELD AVE  4625
# 2  10000095    HY190052  03/18/2015 10:45:00 PM   044XX S LAKE PARK AVE  0486
# 3  10000096    HY190054  03/18/2015 10:30:00 PM    051XX S MICHIGAN AVE  0460
# 4  10000097    HY189976  03/18/2015 09:00:00 PM        047XX W ADAMS ST  031A
#
#     Primary Type              Description Location Description  Arrest  \
# 0        BATTERY      AGGRAVATED: HANDGUN               STREET   False
# 1  OTHER OFFENSE         PAROLE VIOLATION               STREET    True
# 2        BATTERY  DOMESTIC BATTERY SIMPLE            APARTMENT   False
# 3        BATTERY                   SIMPLE            APARTMENT   False
# 4        ROBBERY           ARMED: HANDGUN             SIDEWALK   False
#
#    Domestic  Beat  District  Community Area  Year   Latitude  Longitude
# 0     False  1111        11              25  2015  41.891399 -87.744385
# 1     False   725         7              67  2015  41.773372 -87.665319
# 2      True   222         2              39  2015  41.813861 -87.596643
# 3     False   225         2              40  2015  41.800802 -87.622619
# 4     False  1113        11              25  2015  41.878065 -87.743354

# %%
# Show preview of indicators
indicators_df.head()
# Out:
#        Community Area Number  PERCENT OF HOUSING CROWDED  \
# count              77.000000                   77.000000
# mean               39.000000                    4.923377
# std                22.371857                    3.682887
# min                 1.000000                    0.300000
# 25%                20.000000                    2.300000
# 50%                39.000000                    3.800000
# 75%                58.000000                    6.800000
# max                77.000000                   15.800000
#
#        PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# count                         77.000000                    77.000000
# mean                          21.766234                    15.372727
# std                           11.529957                     7.543412
# min                            3.300000                     4.700000
# 25%                           13.200000                     9.200000
# 50%                           18.900000                    13.900000
# 75%                           29.200000                    20.000000
# max                           56.500000                    35.900000
#
#        PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# count                                     77.000000
# mean                                      20.341558
# std                                       11.823152
# min                                        2.500000
# 25%                                       11.800000
# 50%                                       18.500000
# 75%                                       26.600000
# max                                       54.800000
#
#        PERCENT AGED UNDER 18 OR OVER 64  PER CAPITA INCOME   HARDSHIP INDEX
# count                         77.000000           77.000000       77.000000
# mean                          35.746753        25563.168831       49.506494
# std                            7.327716        15293.098259       28.690556
# min                           13.500000         8201.000000        1.000000
# 25%                           32.000000        15754.000000       25.000000
# 50%                           38.100000        21323.000000       50.000000
# 75%                           40.500000        28887.000000       74.000000
# max                           51.500000        88669.000000       98.000000

# %% [markdown]
# ## Do the stuff for the network creation :D

# %% [markdown]
# ### - First create the csv for the nodes

# %%
import time

start_time = time.time()

nodes_list = []

headers = ["NodeID", 
           "Property1", "Value1", 
           "Property2", "Value2", 
           "Property3", "Value3", 
           "Property4", "Value4",
           "Property5", "Value5"]

# For communities
communities = crimes_df['Community Area'].unique()
communities = np.sort(communities)

for community in communities:
    nodes_list.append(["C{}".format(community), # NodeID
                       'NodeLabel', # Property1
                       'Community', # Value1
                       'Name', # Property2
                       "Community {}".format(community), # Value2
                       np.NAN, # Property3
                       np.NAN, # Value3
                       np.NAN, # Property4
                       np.NAN, # Value4
                       np.NAN, # Property5
                       np.NAN]) # Value5

# For districts
districts = crimes_df['District'].unique()
districts = np.sort(districts)

for district in districts:
    nodes_list.append(["D{}".format(district), #NodeID
                       'NodeLabel', # Property1
                       'District', # Value1
                       'Name', # Property2
                       "District {}".format(district), # Value2
                       np.NAN, # Property3
                       np.NAN, # Value3
                       np.NAN, # Property4
                       np.NAN, # Value4
                       np.NAN, # Property5
                       np.NAN]) # Value5

# For primary type...
crime_types = crimes_df['Primary Type'].unique()
crime_types = np.sort(crime_types)

# for i, crime_type in enumerate(crime_types):
#     nodes_list.append(["CT_{}".format(i), # NodeID
#                        'NodeLabel', # Property1
#                        'CrimeType', # Value1
#                        'Name', # Property2
#                        crime_type, # Value2
#                        '', # Property 3
#                        '']) # Value3

# For case numbers
for index, row in crimes_df.iterrows():
    nodes_list.append(["CASE_{}".format(row['Case Number']), # NodeID
                       'NodeLabel', # Property1
                       'CaseNumber', # Value1
                       'Name', # Property2
                       row['Case Number'], # Value2
                       'Type', # Property3
                       row['Primary Type'], # Value3
                       'Latitude', # Property4
                       row['Latitude'], # Value4
                       'Longitude', # Property5
                       row['Longitude'] ]) # Value5
    
# cases = crimes_df['Case Number'].unique()
# cases = np.sort(cases)

# for case in cases:
#     nodes_list.append(["CASE_{}".format(case) , 
#                        'NodeLabel', 
#                        'CaseNumber', 
#                        'Name', 
#                        case,
#                        ''])

# Create other nodes (based on criterias of indicators and so on)
# Based on hardship
nodes_list.append(["CR_DAN".format(), # NodeID
                   'NodeLabel', # Property1
                   'Category', # Value1
                   'Name', # Property2
                   'Dangereous', # Value2
                   'Comment', # Property3
                   'Bassed on hardship index', # Value3
                   np.NAN, # Property4
                   np.NAN, # Value4
                   np.NAN, # Property5
                   np.NAN]) # Value5

# Create the pandas DataFrame to save the results
nodes_df = pd.DataFrame(nodes_list, columns = headers)

end_time = time.time()
print("Creation of nodes data frame took {:.2f} sec".format(end_time - start_time))

nodes_df
# Out:
# Creation of nodes data frame took 937.41 sec
#                 NodeID  Property1      Value1 Property2        Value2  \
# 0                   C1  NodeLabel   Community      Name   Community 1
# 1                   C2  NodeLabel   Community      Name   Community 2
# 2                   C3  NodeLabel   Community      Name   Community 3
# 3                   C4  NodeLabel   Community      Name   Community 4
# 5855749  CASE_HY186992  NodeLabel  CaseNumber      Name      HY186992
# 5855750  CASE_HY187880  NodeLabel  CaseNumber      Name      HY187880
# 5855751  CASE_HY188050  NodeLabel  CaseNumber      Name      HY188050
# 5855752  CASE_HY188115  NodeLabel  CaseNumber      Name      HY188115
# 5855753  CASE_HY189325  NodeLabel  CaseNumber      Name      HY189325
# 5855754  CASE_JB139324  NodeLabel  CaseNumber      Name      JB139324
# 5855755  CASE_JB139300  NodeLabel  CaseNumber      Name      JB139300
# 5855756         CR_DAN  NodeLabel    Category      Name    Dangereous
#
#         Property3                    Value3 Property4     Value4  Property5  \
# 0             NaN                       NaN       NaN        NaN        NaN
# 1             NaN                       NaN       NaN        NaN        NaN
# 2             NaN                       NaN       NaN        NaN        NaN
# 3             NaN                       NaN       NaN        NaN        NaN
# 4             NaN                       NaN       NaN        NaN        NaN
# 5             NaN                       NaN       NaN        NaN        NaN
# 6             NaN                       NaN       NaN        NaN        NaN
# 7             NaN                       NaN       NaN        NaN        NaN
# 8             NaN                       NaN       NaN        NaN        NaN
# 9             NaN                       NaN       NaN        NaN        NaN
# 10            NaN                       NaN       NaN        NaN        NaN
# 11            NaN                       NaN       NaN        NaN        NaN
# 12            NaN                       NaN       NaN        NaN        NaN
# 13            NaN                       NaN       NaN        NaN        NaN
# 14            NaN                       NaN       NaN        NaN        NaN
# 15            NaN                       NaN       NaN        NaN        NaN
# 16            NaN                       NaN       NaN        NaN        NaN
# 17            NaN                       NaN       NaN        NaN        NaN
# 18            NaN                       NaN       NaN        NaN        NaN
# 19            NaN                       NaN       NaN        NaN        NaN
# 20            NaN                       NaN       NaN        NaN        NaN
# 21            NaN                       NaN       NaN        NaN        NaN
# 22            NaN                       NaN       NaN        NaN        NaN
# 23            NaN                       NaN       NaN        NaN        NaN
# 24            NaN                       NaN       NaN        NaN        NaN
# 25            NaN                       NaN       NaN        NaN        NaN
# 26            NaN                       NaN       NaN        NaN        NaN
# 27            NaN                       NaN       NaN        NaN        NaN
# 28            NaN                       NaN       NaN        NaN        NaN
# 29            NaN                       NaN       NaN        NaN        NaN
# ...           ...                       ...       ...        ...        ...
# 5855727      Type                 NARCOTICS  Latitude  41.885001  Longitude
# 5855728      Type        DECEPTIVE PRACTICE  Latitude  41.893002  Longitude
# 5855729      Type        DECEPTIVE PRACTICE  Latitude  41.651413  Longitude
# 5855730      Type       CRIM SEXUAL ASSAULT  Latitude  41.906262  Longitude
# 5855731      Type                 NARCOTICS  Latitude  41.867472  Longitude
# 5855732      Type                 NARCOTICS  Latitude  41.749295  Longitude
# 5855733      Type                 NARCOTICS  Latitude  41.894263  Longitude
# 5855734      Type                 NARCOTICS  Latitude  41.879687  Longitude
# 5855735      Type                 NARCOTICS  Latitude  41.866793  Longitude
# 5855736      Type                 NARCOTICS  Latitude  41.879247  Longitude
# 5855737      Type                 NARCOTICS  Latitude  41.880741  Longitude
# 5855738      Type        DECEPTIVE PRACTICE  Latitude  41.900421  Longitude
# 5855739      Type           CRIMINAL DAMAGE  Latitude  41.822551  Longitude
# 5855740      Type        DECEPTIVE PRACTICE  Latitude  41.854248  Longitude
# 5855741      Type        DECEPTIVE PRACTICE  Latitude  41.926425  Longitude
# 5855742      Type        DECEPTIVE PRACTICE  Latitude  41.704701  Longitude
# 5855743      Type        DECEPTIVE PRACTICE  Latitude  41.776807  Longitude
# 5855744      Type                     THEFT  Latitude  41.780390  Longitude
# 5855745      Type                   ASSAULT  Latitude  41.921105  Longitude
# 5855746      Type           CRIMINAL DAMAGE  Latitude  41.850709  Longitude
# 5855747      Type        DECEPTIVE PRACTICE  Latitude  41.899048  Longitude
# 5855748      Type        DECEPTIVE PRACTICE  Latitude  41.740207  Longitude
# 5855749      Type        DECEPTIVE PRACTICE  Latitude  41.793810  Longitude
# 5855750      Type        DECEPTIVE PRACTICE  Latitude  41.711661  Longitude
# 5855751      Type        DECEPTIVE PRACTICE  Latitude  41.749853  Longitude
# 5855752      Type        DECEPTIVE PRACTICE  Latitude  41.928606  Longitude
# 5855753      Type        DECEPTIVE PRACTICE  Latitude  41.875713  Longitude
# 5855754      Type                  HOMICIDE  Latitude  41.877370  Longitude
# 5855755      Type                  HOMICIDE  Latitude  41.737261  Longitude
# 5855756   Comment  Bassed on hardship index       NaN        NaN        NaN
#
#             Value5
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 7              NaN
# 8              NaN
# 9              NaN
# 10             NaN
# 11             NaN
# 12             NaN
# 13             NaN
# 14             NaN
# 15             NaN
# 16             NaN
# 17             NaN
# 18             NaN
# 19             NaN
# 20             NaN
# 21             NaN
# 22             NaN
# 23             NaN
# 24             NaN
# 25             NaN
# 26             NaN
# 27             NaN
# 28             NaN
# 29             NaN
# ...            ...
# 5855727 -87.725791
# 5855728 -87.754793
# 5855729 -87.548393
# 5855730 -87.727574
# 5855731 -87.702035
# 5855732 -87.557701
# 5855733 -87.721153
# 5855734 -87.731779
# 5855735 -87.719543
# 5855736 -87.696954
# 5855737 -87.724524
# 5855738 -87.673514
# 5855739 -87.665256
# 5855740 -87.713694
# 5855741 -87.764847
# 5855742 -87.620559
# 5855743 -87.681008
# 5855744 -87.670295
# 5855745 -87.769535
# 5855746 -87.671709
# 5855747 -87.723087
# 5855748 -87.542967
# 5855749 -87.653988
# 5855750 -87.638106
# 5855751 -87.651297
# 5855752 -87.740772
# 5855753 -87.758034
# 5855754 -87.701416
# 5855755 -87.649730
# 5855756        NaN
#
# [5855757 rows x 11 columns]

# %%
# Save nodes for further usage
DATASET_NODES_PATH = DATASETS_LOCATION + "/timewise_nodes.csv"
nodes_df.to_csv(DATASET_NODES_PATH, index = False)

# %% [markdown]
# ### - Now, for the edges...

# %% [markdown]
# #### Relate communties with cases
#
# In theory, this would never change, so we shouldn't modify this cell too much...

# %%
import time

# Log time
start_time = time.time()

# Array to store the edges
edges_list = []

headers = ["EdgeID", "FromNodeID", "ToNodeID",
           "Property1", "Value1", 
           "Property2", "Value2", 
           "Property3", "Value3"]

# Get the communities satisfying a given criteria
communities_criteria = indicators_df[indicators_df['HARDSHIP INDEX'] > 50]

# We iterate over the whole dataset to associate all the cases.
for index, row in crimes_df.iterrows():
    if index % 500000 == 0:
        print("Reached row {} ...".format(index))
    edges_list.append(
        [
            "OCURRED_IN", # EdgeID
            "CASE_" + row['Case Number'], # FromNodeID (A case)
            "C" + str(row['Community Area']), # ToNodeID (A community)
            "StartTime", # Property1
            row['Date'], # Value1. TODO: save start of period we should define
            "EndTime", # Property2
            row['Date'], # Value2. TODO: save end of period we should define
            "Timestamp", # Property3
            row['Date'] # Value3
        ]
    )

pd.DataFrame(edges_list, columns = headers)

edges_df = pd.DataFrame(edges_list, columns = headers)

end_time = time.time()
print("Creation of edges data frame took {:.2f} sec".format(end_time - start_time))

edges_df
# Out:
# Reached row 0 ...
# Reached row 500000 ...
# Reached row 1000000 ...
# Reached row 1500000 ...
# Reached row 2000000 ...
# Reached row 2500000 ...
# Reached row 3000000 ...
# Reached row 3500000 ...
# Reached row 4000000 ...
# Reached row 4500000 ...
# Reached row 5000000 ...
# Reached row 5500000 ...
# Creation of nodes data frame took 768.75 sec
#              EdgeID     FromNodeID ToNodeID  Property1  \
# 0        OCURRED_IN  CASE_HY189866      C25  StartTime
# 1        OCURRED_IN  CASE_HY190059      C67  StartTime
# 2        OCURRED_IN  CASE_HY190052      C39  StartTime
# 3        OCURRED_IN  CASE_HY190054      C40  StartTime
# 4        OCURRED_IN  CASE_HY189976      C25  StartTime
# 5        OCURRED_IN  CASE_HY190032      C39  StartTime
# 6        OCURRED_IN  CASE_HY190047      C68  StartTime
# 7        OCURRED_IN  CASE_HY189988      C38  StartTime
# 8        OCURRED_IN  CASE_HY190020      C59  StartTime
# 9        OCURRED_IN  CASE_HY189964      C49  StartTime
# 10       OCURRED_IN  CASE_HY189984      C54  StartTime
# 11       OCURRED_IN  CASE_HY189719      C69  StartTime
# 12       OCURRED_IN  CASE_HY189966      C46  StartTime
# 13       OCURRED_IN  CASE_HY190056      C28  StartTime
# 14       OCURRED_IN  CASE_HY190019      C25  StartTime
# 15       OCURRED_IN  CASE_HY189725      C43  StartTime
# 16       OCURRED_IN  CASE_HY190071      C24  StartTime
# 17       OCURRED_IN  CASE_HY190036      C67  StartTime
# 18       OCURRED_IN  CASE_HY190063      C49  StartTime
# 19       OCURRED_IN  CASE_HY190068      C48  StartTime
# 20       OCURRED_IN  CASE_HY190031      C43  StartTime
# 21       OCURRED_IN  CASE_HY190072      C77  StartTime
# 22       OCURRED_IN  CASE_HY190073      C43  StartTime
# 23       OCURRED_IN  CASE_HY189969      C25  StartTime
# 24       OCURRED_IN  CASE_HY190060      C31  StartTime
# 25       OCURRED_IN  CASE_HY190035      C40  StartTime
# 26       OCURRED_IN  CASE_HY190027      C73  StartTime
# 27       OCURRED_IN  CASE_HY190096      C71  StartTime
# 28       OCURRED_IN  CASE_HY190003      C71  StartTime
# 29       OCURRED_IN  CASE_HY190101      C51  StartTime
# ...             ...            ...      ...        ...
# 5855625  OCURRED_IN  CASE_HX557982      C26  StartTime
# 5855626  OCURRED_IN  CASE_HX557984      C26  StartTime
# 5855627  OCURRED_IN  CASE_HY171695      C25  StartTime
# 5855628  OCURRED_IN  CASE_HY171649      C55  StartTime
# 5855629  OCURRED_IN  CASE_HY173580      C23  StartTime
# 14       03/18/2015 10:31:00 PM   EndTime  03/18/2015 10:31:00 PM  Timestamp
# 15       03/18/2015 12:55:00 PM   EndTime  03/18/2015 12:55:00 PM  Timestamp
# 16       03/18/2015 08:00:00 PM   EndTime  03/18/2015 08:00:00 PM  Timestamp
# 17       03/18/2015 09:00:00 PM   EndTime  03/18/2015 09:00:00 PM  Timestamp
# 18       03/18/2015 10:56:00 PM   EndTime  03/18/2015 10:56:00 PM  Timestamp
# 19       03/18/2015 10:45:00 PM   EndTime  03/18/2015 10:45:00 PM  Timestamp
# 20       03/18/2015 10:00:00 PM   EndTime  03/18/2015 10:00:00 PM  Timestamp
# 21       03/18/2015 11:55:00 PM   EndTime  03/18/2015 11:55:00 PM  Timestamp
# 22       03/18/2015 11:40:00 PM   EndTime  03/18/2015 11:40:00 PM  Timestamp
# 23       03/18/2015 09:44:00 PM   EndTime  03/18/2015 09:44:00 PM  Timestamp
# 24       03/18/2015 11:30:00 PM   EndTime  03/18/2015 11:30:00 PM  Timestamp
# 25       03/18/2015 10:45:00 PM   EndTime  03/18/2015 10:45:00 PM  Timestamp
# 26       03/18/2015 10:33:00 PM   EndTime  03/18/2015 10:33:00 PM  Timestamp
# 27       03/19/2015 01:20:00 AM   EndTime  03/19/2015 01:20:00 AM  Timestamp
# 28       03/18/2015 09:59:00 PM   EndTime  03/18/2015 09:59:00 PM  Timestamp
# 29       03/19/2015 01:28:00 AM   EndTime  03/19/2015 01:28:00 AM  Timestamp
# ...                         ...       ...                     ...        ...
# 5855625  12/28/2014 07:15:00 PM   EndTime  12/28/2014 07:15:00 PM  Timestamp
# 5855626  12/28/2014 07:40:00 PM   EndTime  12/28/2014 07:40:00 PM  Timestamp
# 5855627  02/01/2010 12:01:00 AM   EndTime  02/01/2010 12:01:00 AM  Timestamp
# 5855628  01/01/2012 12:00:00 PM   EndTime  01/01/2012 12:00:00 PM  Timestamp
# 5855629  09/01/2012 10:00:00 AM   EndTime  09/01/2012 10:00:00 AM  Timestamp
# 5855630  12/17/2014 03:40:00 PM   EndTime  12/17/2014 03:40:00 PM  Timestamp
# 5855631  12/16/2014 04:19:00 PM   EndTime  12/16/2014 04:19:00 PM  Timestamp
# 5855632  12/16/2014 12:12:00 PM   EndTime  12/16/2014 12:12:00 PM  Timestamp
# 5855633  12/16/2014 04:15:00 PM   EndTime  12/16/2014 04:15:00 PM  Timestamp
# 5855634  12/27/2014 12:20:00 PM   EndTime  12/27/2014 12:20:00 PM  Timestamp
# 5855635  12/26/2014 04:17:00 PM   EndTime  12/26/2014 04:17:00 PM  Timestamp
# 5855636  12/26/2014 06:55:00 PM   EndTime  12/26/2014 06:55:00 PM  Timestamp
# 5855637  02/07/2012 09:00:00 AM   EndTime  02/07/2012 09:00:00 AM  Timestamp
# 5855638  03/12/2015 07:00:00 AM   EndTime  03/12/2015 07:00:00 AM  Timestamp
# 5855639  04/01/2012 12:01:00 AM   EndTime  04/01/2012 12:01:00 AM  Timestamp
# 5855632  12/16/2014 12:12:00 PM
# 5855633  12/16/2014 04:15:00 PM
# 5855634  12/27/2014 12:20:00 PM
# 5855635  12/26/2014 04:17:00 PM
# 5855636  12/26/2014 06:55:00 PM
# 5855637  02/07/2012 09:00:00 AM
# 5855638  03/12/2015 07:00:00 AM
# 5855639  04/01/2012 12:01:00 AM
# 5855640  10/01/2011 08:00:00 AM
# 5855641  01/13/2011 09:00:00 AM
# 5855642  03/11/2011 09:00:00 AM
# 5855643  03/11/2015 12:00:00 PM
# 5855644  03/13/2015 06:00:00 PM
# 5855645  03/14/2015 09:00:00 PM
# 5855646  11/14/2011 11:44:00 AM
# 5855647  02/11/2011 07:00:00 AM
# 5855648  09/26/2011 09:00:00 AM
# 5855649  03/01/2011 12:00:00 PM
# 5855650  01/01/2010 12:00:00 AM
# 5855651  01/01/2012 09:00:00 AM
# 5855652  05/05/2011 12:00:00 PM
# 5855653  02/02/2018 10:25:00 PM
# 5855654  02/02/2018 09:51:00 PM
#
# [5855655 rows x 9 columns]

# %% [markdown]
# #### Relate communities with categories (dangereous, poor, etc...)

# %%
# This cell appends the content. So, if you run it multiple times, you will add multiple times.
# Proceed carefully...

import time

# Log time
start_time = time.time()

# Get the communities satisfying a given criteria
communities_criteria = indicators_df[indicators_df['HARDSHIP INDEX'] > 50]

for index, row in communities_criteria.iterrows():
    edges_list.append(
        [
            "CONSIDERED", # EdgeID
            "C" + str(row['Community Area Number']), # FromNodeID (A community)
            "CR_DAN", # ToNodeID (A criteria node)
            "HardshipIndex", # Property1
            row['HARDSHIP INDEX'], # Value1
            np.NaN, # Property2
            np.NaN, # Value2
            np.NaN, # Property3
            np.NaN  # Value3
        ]
    )

edges_df = pd.DataFrame(edges_list, columns = headers)

end_time = time.time()
print("Append to edges data frame took {:.2f} sec".format(end_time - start_time))

edges_df
# Out:
# Creation of nodes data frame took 9.33 sec
#              EdgeID     FromNodeID ToNodeID      Property1  \
# 0        OCURRED_IN  CASE_HY189866      C25      StartTime
# 1        OCURRED_IN  CASE_HY190059      C67      StartTime
# 2        OCURRED_IN  CASE_HY190052      C39      StartTime
# 3        OCURRED_IN  CASE_HY190054      C40      StartTime
# 4        OCURRED_IN  CASE_HY189976      C25      StartTime
# 5        OCURRED_IN  CASE_HY190032      C39      StartTime
# 6        OCURRED_IN  CASE_HY190047      C68      StartTime
# 7        OCURRED_IN  CASE_HY189988      C38      StartTime
# 8        OCURRED_IN  CASE_HY190020      C59      StartTime
# 9        OCURRED_IN  CASE_HY189964      C49      StartTime
# 10       OCURRED_IN  CASE_HY189984      C54      StartTime
# 11       OCURRED_IN  CASE_HY189719      C69      StartTime
# 12       OCURRED_IN  CASE_HY189966      C46      StartTime
# 13       OCURRED_IN  CASE_HY190056      C28      StartTime
# 14       OCURRED_IN  CASE_HY190019      C25      StartTime
# 15       OCURRED_IN  CASE_HY189725      C43      StartTime
# 16       OCURRED_IN  CASE_HY190071      C24      StartTime
# 17       OCURRED_IN  CASE_HY190036      C67      StartTime
# 18       OCURRED_IN  CASE_HY190063      C49      StartTime
# 19       OCURRED_IN  CASE_HY190068      C48      StartTime
# 20       OCURRED_IN  CASE_HY190031      C43      StartTime
# 21       OCURRED_IN  CASE_HY190072      C77      StartTime
# 22       OCURRED_IN  CASE_HY190073      C43      StartTime
# 23       OCURRED_IN  CASE_HY189969      C25      StartTime
# 24       OCURRED_IN  CASE_HY190060      C31      StartTime
# 25       OCURRED_IN  CASE_HY190035      C40      StartTime
# 26       OCURRED_IN  CASE_HY190027      C73      StartTime
# 27       OCURRED_IN  CASE_HY190096      C71      StartTime
# 28       OCURRED_IN  CASE_HY190003      C71      StartTime
# 29       OCURRED_IN  CASE_HY190101      C51      StartTime
# ...             ...            ...      ...            ...
# 5855663  CONSIDERED            C30   CR_DAN  HardshipIndex
# 5855664  CONSIDERED            C31   CR_DAN  HardshipIndex
# 5855665  CONSIDERED            C34   CR_DAN  HardshipIndex
# 5855666  CONSIDERED            C36   CR_DAN  HardshipIndex
# 5855667  CONSIDERED            C37   CR_DAN  HardshipIndex
# 5855668  CONSIDERED            C38   CR_DAN  HardshipIndex
# 5855669  CONSIDERED            C40   CR_DAN  HardshipIndex
# 5855670  CONSIDERED            C42   CR_DAN  HardshipIndex
# 5855671  CONSIDERED            C43   CR_DAN  HardshipIndex
# 5855672  CONSIDERED            C44   CR_DAN  HardshipIndex
# 5855673  CONSIDERED            C46   CR_DAN  HardshipIndex
# 5855674  CONSIDERED            C47   CR_DAN  HardshipIndex
# 5855675  CONSIDERED            C49   CR_DAN  HardshipIndex
# 5855676  CONSIDERED            C50   CR_DAN  HardshipIndex
# 5855677  CONSIDERED            C51   CR_DAN  HardshipIndex
# 5855678  CONSIDERED            C52   CR_DAN  HardshipIndex
# 5855679  CONSIDERED            C53   CR_DAN  HardshipIndex
# 5855680  CONSIDERED            C54   CR_DAN  HardshipIndex
# 5855681  CONSIDERED            C57   CR_DAN  HardshipIndex
# 5855682  CONSIDERED            C58   CR_DAN  HardshipIndex
# 5855683  CONSIDERED            C59   CR_DAN  HardshipIndex
# 5855684  CONSIDERED            C61   CR_DAN  HardshipIndex
# 5855685  CONSIDERED            C62   CR_DAN  HardshipIndex
# 5855686  CONSIDERED            C63   CR_DAN  HardshipIndex
# 5855687  CONSIDERED            C65   CR_DAN  HardshipIndex
# 5855688  CONSIDERED            C66   CR_DAN  HardshipIndex
# 5855689  CONSIDERED            C67   CR_DAN  HardshipIndex
# 5855690  CONSIDERED            C68   CR_DAN  HardshipIndex
# 5855691  CONSIDERED            C69   CR_DAN  HardshipIndex
# 5855692  CONSIDERED            C71   CR_DAN  HardshipIndex
#
#                          Value1 Property2                  Value2  Property3  \
# 0        03/18/2015 07:44:00 PM   EndTime  03/18/2015 07:44:00 PM  Timestamp
# 1        03/18/2015 11:00:00 PM   EndTime  03/18/2015 11:00:00 PM  Timestamp
# 2        03/18/2015 10:45:00 PM   EndTime  03/18/2015 10:45:00 PM  Timestamp
# 3        03/18/2015 10:30:00 PM   EndTime  03/18/2015 10:30:00 PM  Timestamp
# 4        03/18/2015 09:00:00 PM   EndTime  03/18/2015 09:00:00 PM  Timestamp
# 5        03/18/2015 10:00:00 PM   EndTime  03/18/2015 10:00:00 PM  Timestamp
# 6        03/18/2015 11:00:00 PM   EndTime  03/18/2015 11:00:00 PM  Timestamp
# 7        03/18/2015 09:35:00 PM   EndTime  03/18/2015 09:35:00 PM  Timestamp
# 8        03/18/2015 10:09:00 PM   EndTime  03/18/2015 10:09:00 PM  Timestamp
# 9        03/18/2015 09:25:00 PM   EndTime  03/18/2015 09:25:00 PM  Timestamp
# 10       03/18/2015 09:30:00 PM   EndTime  03/18/2015 09:30:00 PM  Timestamp
# 11       03/15/2015 04:10:00 PM   EndTime  03/15/2015 04:10:00 PM  Timestamp
# 12       03/18/2015 09:14:00 PM   EndTime  03/18/2015 09:14:00 PM  Timestamp
# 13       03/18/2015 10:50:00 PM   EndTime  03/18/2015 10:50:00 PM  Timestamp
# 14       03/18/2015 10:31:00 PM   EndTime  03/18/2015 10:31:00 PM  Timestamp
# 15       03/18/2015 12:55:00 PM   EndTime  03/18/2015 12:55:00 PM  Timestamp
# 16       03/18/2015 08:00:00 PM   EndTime  03/18/2015 08:00:00 PM  Timestamp
# 17       03/18/2015 09:00:00 PM   EndTime  03/18/2015 09:00:00 PM  Timestamp
# 18       03/18/2015 10:56:00 PM   EndTime  03/18/2015 10:56:00 PM  Timestamp
# 19       03/18/2015 10:45:00 PM   EndTime  03/18/2015 10:45:00 PM  Timestamp
# 20       03/18/2015 10:00:00 PM   EndTime  03/18/2015 10:00:00 PM  Timestamp
# 21       03/18/2015 11:55:00 PM   EndTime  03/18/2015 11:55:00 PM  Timestamp
# 22       03/18/2015 11:40:00 PM   EndTime  03/18/2015 11:40:00 PM  Timestamp
# 23       03/18/2015 09:44:00 PM   EndTime  03/18/2015 09:44:00 PM  Timestamp
# 24       03/18/2015 11:30:00 PM   EndTime  03/18/2015 11:30:00 PM  Timestamp
# 25       03/18/2015 10:45:00 PM   EndTime  03/18/2015 10:45:00 PM  Timestamp
# 26       03/18/2015 10:33:00 PM   EndTime  03/18/2015 10:33:00 PM  Timestamp
# 27       03/19/2015 01:20:00 AM   EndTime  03/19/2015 01:20:00 AM  Timestamp
# 28       03/18/2015 09:59:00 PM   EndTime  03/18/2015 09:59:00 PM  Timestamp
# 29       03/19/2015 01:28:00 AM   EndTime  03/19/2015 01:28:00 AM  Timestamp
# ...                         ...       ...                     ...        ...
# 5855663                      96       NaN                     NaN        NaN
# 5855664                      76       NaN                     NaN        NaN
# 5855665                      82       NaN                     NaN        NaN
# 5855666                      78       NaN                     NaN        NaN
# 5855667                      97       NaN                     NaN        NaN
# 5855668                      57       NaN                     NaN        NaN
# 5855669                      88       NaN                     NaN        NaN
# 5855670                      58       NaN                     NaN        NaN
# 5855671                      55       NaN                     NaN        NaN
# 5855672                      60       NaN                     NaN        NaN
# 5855673                      75       NaN                     NaN        NaN
# 5855674                      79       NaN                     NaN        NaN
# 5855675                      52       NaN                     NaN        NaN
# 5855676                      51       NaN                     NaN        NaN
# 5855677                      65       NaN                     NaN        NaN
# 5855678                      64       NaN                     NaN        NaN
# 5855679                      62       NaN                     NaN        NaN
# 5855680                      98       NaN                     NaN        NaN
# 5855681                      67       NaN                     NaN        NaN
# 5855682                      84       NaN                     NaN        NaN
# 5855683                      61       NaN                     NaN        NaN
# 5855684                      91       NaN                     NaN        NaN
# 5855685                      69       NaN                     NaN        NaN
# 5855686                      93       NaN                     NaN        NaN
# 5855687                      56       NaN                     NaN        NaN
# 5855688                      80       NaN                     NaN        NaN
# 5855689                      89       NaN                     NaN        NaN
# 5855690                      94       NaN                     NaN        NaN
# 5855691                      66       NaN                     NaN        NaN
# 5855692                      74       NaN                     NaN        NaN
#
#                          Value3
# 0        03/18/2015 07:44:00 PM
# 1        03/18/2015 11:00:00 PM
# 2        03/18/2015 10:45:00 PM
# 3        03/18/2015 10:30:00 PM
# 4        03/18/2015 09:00:00 PM
# 5        03/18/2015 10:00:00 PM
# 6        03/18/2015 11:00:00 PM
# 7        03/18/2015 09:35:00 PM
# 8        03/18/2015 10:09:00 PM
# 9        03/18/2015 09:25:00 PM
# 10       03/18/2015 09:30:00 PM
# 11       03/15/2015 04:10:00 PM
# 12       03/18/2015 09:14:00 PM
# 13       03/18/2015 10:50:00 PM
# 14       03/18/2015 10:31:00 PM
# 15       03/18/2015 12:55:00 PM
# 16       03/18/2015 08:00:00 PM
# 17       03/18/2015 09:00:00 PM
# 18       03/18/2015 10:56:00 PM
# 19       03/18/2015 10:45:00 PM
# 20       03/18/2015 10:00:00 PM
# 21       03/18/2015 11:55:00 PM
# 22       03/18/2015 11:40:00 PM
# 23       03/18/2015 09:44:00 PM
# 24       03/18/2015 11:30:00 PM
# 25       03/18/2015 10:45:00 PM
# 26       03/18/2015 10:33:00 PM
# 27       03/19/2015 01:20:00 AM
# 28       03/18/2015 09:59:00 PM
# 29       03/19/2015 01:28:00 AM
# ...                         ...
# 5855663                     NaN
# 5855664                     NaN
# 5855665                     NaN
# 5855666                     NaN
# 5855667                     NaN
# 5855668                     NaN
# 5855669                     NaN
# 5855670                     NaN
# 5855671                     NaN
# 5855672                     NaN
# 5855673                     NaN
# 5855674                     NaN
# 5855675                     NaN
# 5855676                     NaN
# 5855677                     NaN
# 5855678                     NaN
# 5855679                     NaN
# 5855680                     NaN
# 5855681                     NaN
# 5855682                     NaN
# 5855683                     NaN
# 5855684                     NaN
# 5855685                     NaN
# 5855686                     NaN
# 5855687                     NaN
# 5855688                     NaN
# 5855689                     NaN
# 5855690                     NaN
# 5855691                     NaN
# 5855692                     NaN
#
# [5855693 rows x 9 columns]

# %%
# Save nodes for further usage
DATASET_NODES_PATH = DATASETS_LOCATION + "/timewise_edges.csv"
edges_df.to_csv(DATASET_NODES_PATH, index = False)
